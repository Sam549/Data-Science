# %% [markdown]
# # PROJECT

# %% [markdown]
# ## Reading dataset

# %%
import pandas as pd
data=pd.read_csv("Book2.csv")
print(data.head())
# Out:
#    GROUP ID  MATCH ID  ASSISTS  BOOST  DAMAGE DEALT  DBNOs  HEADSHOT  HEAL  \
# 0     48622     23184       13      1           168      3        14     5
# 1     50532     52307       21     13           355     29         3     5
# 2     82222     32021       58      8           157      9        12     5
# 3     97906     56717       47      1           660     11         3     2
# 4     80677     83052       16     14           384      0         2     3
#
#    KILL PLACE  KILL POINTS  ...  REVIVE  RIDE DISTANCE  ROAD KILLS  \
# 0          95           37  ...       7            524           3
# 1          28           31  ...       1            177           3
# 2          43           12  ...       0            533           0
# 3          56           61  ...       2            405           7
# 4          32           26  ...       4            317           5
#
#    SWIM DISTANCE  TEAM KILLS  VECHILEDESTROY  WALK DISTANCE  WEAPONS ACQUIRED  \
# ...

# %% [markdown]
# ## Checking datatype

# %%
print(type(data["TEAM KILLS"]))
print(type(data["WIN POINTS"]))
print(type(data["GROUP ID"]))
print(type(data["MATCH ID"]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## Numerical Columns

# %%
num_col=data.describe().columns
df=data[num_col]
print(df)
# Out:
#     GROUP ID  MATCH ID  ASSISTS  BOOST  DAMAGE DEALT  DBNOs  HEADSHOT  HEAL  \
# 0      48622     23184       13      1           168      3        14     5
# 1      50532     52307       21     13           355     29         3     5
# 2      82222     32021       58      8           157      9        12     5
# 3      97906     56717       47      1           660     11         3     2
# 4      80677     83052       16     14           384      0         2     3
# ..       ...       ...      ...    ...           ...    ...       ...   ...
# 95     77009     79550       15      5           608     23        12     5
# 96     81415     63102       24      1           704     17         2     1
# 97     63678     18064        4     14           729     17         7     3
# 98     67034     73440       36      9           151     24         9     2
# 99     92239     43475        3      2           585      3        12     3
#
# ...

# %% [markdown]
# ## Average kills

# %%
df1=data["KILLS"].mean()
print(df1)
# Out:
# 29.29

# %% [markdown]
# ## Kills by 99%

# %%
kb99=data["KILLS"]
print(((kb99/900)).mean())
# Out:
# 0.03254444444444446

# %% [markdown]
# ##  Max Recorded kills

# %%
print(kb99.max())
# Out:
# 59

# %% [markdown]
# ## Columns of dataframe

# %%
print(data.columns)
# Out:
# Index(['GROUP ID', 'MATCH ID', 'ASSISTS', 'BOOST', 'DAMAGE DEALT', 'DBNOs',
#        'HEADSHOT', 'HEAL', 'KILL PLACE', 'KILL POINTS', 'KILLS', 'KILL STREAK',
#        'LONGEST KILL', 'MAX PLACE', 'NUM GROUPS', 'REVIVE', 'RIDE DISTANCE',
#        'ROAD KILLS', 'SWIM DISTANCE', 'TEAM KILLS', 'VECHILEDESTROY',
#        'WALK DISTANCE', 'WEAPONS ACQUIRED', 'WIN POINTS', 'WIN PLACE PERC'],
#       dtype='object')

# %% [markdown]
# ## Distribution of match duration

# %%
import seaborn as sb
print(sb.distplot(data["WIN POINTS"]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# ## Distribution of Walk Distance

# %%
import seaborn as sb
print(sb.distplot(data["WALK DISTANCE"]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# ## Match duration and Walk Distance

# %%
print(sb.barplot(x="WIN POINTS",y="WALK DISTANCE",data=data));
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
import seaborn as sb
import pandas as pd
data=pd.read_csv("Book2.csv")
print(sb.pairplot(data));

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-74c4a8db91a9> in <module>
#       1 import seaborn as sb
#       2 data=pd.read_csv("Book2.csv")
# ----> 3 print(sb.pairplot(x="MAX PLACE",y="NUM GROUPS",data=data));
#
# TypeError: pairplot() got an unexpected keyword argument 'x'

# %%
import pandas as pd
data=pd.read_csv("Book2.csv")
print(data["MATCH TYPE"].unique())
# Out:
# ['ERANGEL' 'SANHOK' 'VIKENDI' 'MIRAMAR']

# %%
sb.barplot(x="MATCH TYPE",y="KILL POINTS",data=data)

# %%
sb.barplot(x="MATCH TYPE",y="WEAPONS ACQUIRED",data=data)

# %%
sb.boxplot(x="MATCH TYPE",y="WIN PLACE PERC",data=data)

# %%
sb.boxplot(x="MATCH TYPE",y="WIN POINTS",data=data)

# %%
data["KILL"]=data["HEADSHOT"]+data["TEAM KILLS"]+data["ROAD KILLS"]
print(data["KILL"])
# Out:
# 0     29
# 1     29
# 2     19
# 3     29
# 4     20
#       ..
# 95    23
# 96    19
# 97    16
# 98    24
# 99    39
# Name: KILL, Length: 100, dtype: int64
